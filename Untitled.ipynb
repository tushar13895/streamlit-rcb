# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot  as plt

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

from sklearn.cluster import DBSCAN

# %%
df_ball = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv')

# %%
df_match = pd.read_csv('IPL Matches 2008-2020.csv')

# %%
# Group details on batsmen
batgroup = df_ball.groupby(['batsman'])

# Create a batting dataframe with a summary statistics for each batsman
batdf = pd.DataFrame(batgroup['ball'].count()).rename(columns={'ball':'balls_faced'})
batdf['innings'] = batgroup['id'].nunique()
batdf['runs'] = batgroup['batsman_runs'].sum()
batdf['4s'] = df_ball[df_ball['batsman_runs'] == 4].groupby('batsman')['batsman_runs'].count()
batdf['4s'].fillna(0,inplace=True)
batdf['6s'] = df_ball[df_ball['batsman_runs'] == 6].groupby('batsman')['batsman_runs'].count()
batdf['6s'].fillna(0,inplace=True)

# Batting average = total rus scored/no. of times batsman is been dismissed
# Approximated here to matches instead of no. of dismissals
batdf['bat_average'] = round(batdf['runs']/batdf['innings'],2)

# Strike Rate = (Runs Scored / Balls faced) * 100
batdf['bat_strike'] = round(batdf['runs']/batdf['balls_faced']*100,2)

# %%
bowlgroup = df_ball.groupby(['bowler'])

# Create a bowling dataframe (bowldf) with a summary statistics for each batsman
bowldf = pd.DataFrame(bowlgroup['ball'].count()).rename(columns={'ball':'balls_bowled'})

# Get no. of wickets taken by each bowler
bwl_wkts = df_ball[df_ball['dismissal_kind'].isin(['caught','bowled', 'lbw','stumped', 'caught and bowled', 'hit wicket'])]
bowldf['wickets'] = bwl_wkts.groupby(['bowler'])['ball'].count()
bowldf['wickets'].fillna(0,inplace=True)
 
# Calculate the total no. of overs bowled
overs = pd.DataFrame(df_ball.groupby(['bowler','id'])['over'].nunique())
bowldf['overs'] = overs.groupby(['bowler'])['over'].sum()    

# Calculate the runs conceded
bowldf['runs_conceded'] = df_ball.groupby('bowler')['batsman_runs'].sum()
bowldf['runs_conceded'] = bowldf['runs_conceded'].fillna(0)
# Add the runs conceded through wide and noball
bowldf['runs_conceded'] = bowldf['runs_conceded'].add(df_ball[df_ball['extras_type'].isin(['wides','noballs'])].groupby('bowler')['extra_runs'].sum(),fill_value=0)

# Note - roughly apprx to overs.  Should be runs_conceded/overs.balls
bowldf['bowl_econ'] = round(bowldf['runs_conceded']/bowldf['overs'],2)

# %%
# Add each player to the final all players list
def update_player_with_match(player_name, id):
    if player_name in all_players_dict:
        all_players_dict[player_name].add(id)
    else:
        all_players_dict[player_name] = {id}

# Consider players listed as batsman, non striker or bowler
def update_player_list(x):
    update_player_with_match(x['batsman'],x['id'])
    update_player_with_match(x['non_striker'],x['id'])
    update_player_with_match(x['bowler'],x['id']) 
        
# Create a dataframe with all players list
all_players_dict = {}
out_temp = df_ball.apply(lambda x: update_player_list(x),axis=1)
all_df = pd.DataFrame({'Players':list(all_players_dict.keys())})
all_df['matches'] = all_df['Players'].apply(lambda x: len(all_players_dict[x]))
all_df=all_df.set_index('Players')

# %%
# Combine the batting and bowling dataframes to create a merged players dataframe
players = pd.merge(all_df,batdf, left_index=True, right_index=True,how='outer')
players = pd.merge(players,bowldf, left_index=True, right_index=True,how='outer')

# Number of man of the matches from matches file
players = pd.merge(players,df_match['player_of_match'].value_counts(), left_index=True, right_index=True,how='left')
players['player_of_match']  = players[['player_of_match']].fillna(0)

# %%
players.tail()
# Out:
#                matches  balls_faced  innings    runs     4s     6s  \
# YV Takawale         10        183.0     10.0   192.0   26.0    3.0
# Yashpal Singh        4         67.0      4.0    47.0    5.0    0.0
# Younis Khan          1          7.0      1.0     3.0    0.0    0.0
# Yuvraj Singh       129       2205.0    126.0  2750.0  217.0  149.0
# Z Khan              99        141.0     27.0   117.0   11.0    2.0
#
#                bat_average  bat_strike  balls_bowled  wickets  overs  \
# YV Takawale          19.20      104.92           NaN      NaN    NaN
# Yashpal Singh        11.75       70.15           NaN      NaN    NaN
# Younis Khan           3.00       42.86           NaN      NaN    NaN
# Yuvraj Singh         21.83      124.72         882.0     36.0  146.0
# Z Khan                4.33       82.98        2276.0    102.0  371.0
#
#                runs_conceded  bowl_econ  player_of_match
# YV Takawale              NaN        NaN              0.0
# Yashpal Singh            NaN        NaN              0.0
# Younis Khan              NaN        NaN              0.0
# Yuvraj Singh          1077.0       7.38              5.0
# Z Khan                2782.0       7.50              1.0

# %%
df_ball['dismissal_kind'].unique()
# Total catches = Number of caught & bowled + number of catches as fielder
# Capture caught & bowled instances
catches_cb = df_ball[(df_ball['dismissal_kind'].isin(['caught and bowled']))].groupby('bowler')['ball'].count().rename('bowler_catches')
# Capture the catches
catches_c = df_ball[(df_ball['dismissal_kind'].isin(['caught']))].groupby('fielder')['ball'].count().rename('fielder_catches')
# Combine the caught & bowled and fielding catches to get the total catches.
catches_df = pd.merge(catches_cb,catches_c, left_index=True, right_index=True,how='outer')
catches_df.fillna(0,inplace=True)
catches_df['catches'] = catches_df['bowler_catches']+catches_df['fielder_catches']
catches_df.drop(['bowler_catches','fielder_catches'],axis=1,inplace=True)
# Merge total catches to players data
players = pd.merge(players,catches_df, left_index=True, right_index=True,how='outer')
players.fillna(0,inplace=True)

# %%
# Backup before data filtering
all_players = players.copy()

ALL_COLUMN_NAMES = list(players.columns)
players.shape
sns.displot(players['matches'],kde=True)
plt.title('Distribution of matches played (before filtering)')
plt.show()

# %%
# Cut off on no. of matches

# Current Analysis: Players who have played atleast 10 matches
CUTOFF_MATCHES = 10
players=players[players['matches']>=CUTOFF_MATCHES]

# %%
players.shape
# Out:
# (336, 15)

# %%
sns.displot(players['matches'],kde=True)
plt.title('Distribution of matches played (after filtering)')
plt.show()

# %%
players.head()
# Out:
#                 matches  balls_faced  innings   runs    4s    6s  bat_average  \
# A Ashish Reddy     28.0        196.0     23.0  280.0  16.0  15.0        12.17
# A Chandila         12.0          7.0      2.0    4.0   0.0   0.0         2.00
# A Kumble           42.0         49.0     15.0   35.0   3.0   0.0         2.33
# A Mishra          150.0        410.0     54.0  362.0  29.0   5.0         6.70
# A Mithun           16.0         26.0      6.0   34.0   4.0   1.0         5.67
#
#                 bat_strike  balls_bowled  wickets  overs  runs_conceded  \
# A Ashish Reddy      142.86         270.0     18.0   45.0          396.0
# A Chandila           57.14         234.0     11.0   39.0          242.0
# A Kumble             71.43         983.0     45.0  163.0         1058.0
# A Mishra             88.29        3233.0    160.0  529.0         3867.0
# A Mithun            130.77         312.0      7.0   48.0          472.0
#
#                 bowl_econ  player_of_match  catches
# A Ashish Reddy       8.80              0.0      9.0
# A Chandila           6.21              1.0      7.0
# A Kumble             6.49              3.0     10.0
# A Mishra             7.31             11.0     21.0
# A Mithun             9.83              0.0      7.0

# %%
sns.scatterplot(data=players, x="runs", y="wickets")
plt.title("Runs vs wickets")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Standard Scaler (mean = 0 and standard deviation = 1)
scaler = StandardScaler()

# fit_transform
players_scaled = pd.DataFrame(scaler.fit_transform(players),columns=players.columns)
players_scaled.shape
players_scaled.head()


# TESTING -  CONSIDER  ONLY RUNS AND WICKETS
#players_scaled  = players_scaled[['runs','wickets','catches']]
# Out:
#     matches  balls_faced   innings      runs        4s        6s  bat_average  \
# 0 -0.480732    -0.421936 -0.284259 -0.375626 -0.450860 -0.242263    -0.121512
# 1 -0.861802    -0.644246 -0.813057 -0.627066 -0.603947 -0.575235    -1.210416
# 2 -0.147296    -0.594844 -0.485706 -0.598825 -0.575244 -0.575235    -1.175083
# 3  2.424926    -0.170219  0.496348 -0.300922 -0.326477 -0.464245    -0.707186
# 4 -0.766535    -0.621897 -0.712334 -0.599736 -0.565676 -0.553037    -0.817468
#
#    bat_strike  balls_bowled   wickets     overs  runs_conceded  bowl_econ  \
# 0    1.125984     -0.384855 -0.187779 -0.374215      -0.335988   0.676402
# 1   -1.622592     -0.435834 -0.400011 -0.426504      -0.512530  -0.031829
# 2   -1.164389      0.624825  0.630832  0.654125       0.422914   0.044736
# 3   -0.623780      3.811051  4.117509  3.843723       3.643088   0.268964
# 4    0.738323     -0.325379 -0.521287 -0.348071      -0.248863   0.958054
#
#    player_of_match   catches
# 0        -0.653874 -0.391400
# 1        -0.376823 -0.494182
# 2         0.177280 -0.340008
# 3         2.393691  0.225296
# 4        -0.653874 -0.494182

# %%
players.insert(0, 'name', players.index)

# %%
players.head()
# Out:
#                           name  matches  balls_faced  innings   runs    4s  \
# A Ashish Reddy  A Ashish Reddy     28.0        196.0     23.0  280.0  16.0
# A Chandila          A Chandila     12.0          7.0      2.0    4.0   0.0
# A Kumble              A Kumble     42.0         49.0     15.0   35.0   3.0
# A Mishra              A Mishra    150.0        410.0     54.0  362.0  29.0
# A Mithun              A Mithun     16.0         26.0      6.0   34.0   4.0
#
#                   6s  bat_average  bat_strike  balls_bowled  wickets  overs  \
# A Ashish Reddy  15.0        12.17      142.86         270.0     18.0   45.0
# A Chandila       0.0         2.00       57.14         234.0     11.0   39.0
# A Kumble         0.0         2.33       71.43         983.0     45.0  163.0
# A Mishra         5.0         6.70       88.29        3233.0    160.0  529.0
# A Mithun         1.0         5.67      130.77         312.0      7.0   48.0
#
#                 runs_conceded  bowl_econ  player_of_match  catches
# A Ashish Reddy          396.0       8.80              0.0      9.0
# A Chandila              242.0       6.21              1.0      7.0
# A Kumble               1058.0       6.49              3.0     10.0
# A Mishra               3867.0       7.31             11.0     21.0
# A Mithun                472.0       9.83              0.0      7.0

# %%
# Method to compute the silhouette score for the given input
def compute_silhouette_score(input_df, min_k, max_k, k_max_iter):
    # silhouette analysis
    k_range = range(min_k, max_k+1)

    for k in k_range :
        # intialise kmeans
        kmeans = KMeans(n_clusters=k, max_iter=k_max_iter)
        kmeans.fit(input_df)
        cluster_labels = kmeans.labels_

        # silhouette score
        silhouette_avg = silhouette_score(input_df, cluster_labels)
        print(f"For k={k}, silhouette score = {silhouette_avg}")

# %%
compute_silhouette_score(players_scaled, 2,12,300)
# Out:
# For k=2, silhouette score = 0.48803222136569746
# For k=3, silhouette score = 0.4433088208407482
# For k=4, silhouette score = 0.3975620480608323
# For k=5, silhouette score = 0.2802189699769682
# For k=6, silhouette score = 0.3054395335904012
# For k=7, silhouette score = 0.3152133012643455
# For k=8, silhouette score = 0.32026701831359766
# For k=9, silhouette score = 0.3241932726780091
# For k=10, silhouette score = 0.3139275134820013
# For k=11, silhouette score = 0.310490783139626
# For k=12, silhouette score = 0.3111950755579693

# %%
NUM_CLUSTERS = 5

# %%
# Initialize few colour codes for each cluster
CLUSTER_COLORS = ['#F28A30','#0ABDA0','#008AC5','#D6618F','#F3CD05','#A882C1','#BDA589','#888C46',
                  '#36688D','#00743F','#0444BF','#A7414A','#1D65A6','red','green','blue','orange','pink','yellow']

# %%
def print_with_column_color_style(input_df):

    col_bgcolor_dict = dict(zip(input_df.columns,['background-color:'+i for i in CLUSTER_COLORS]))
    def mycolor(x):
        return pd.DataFrame(col_bgcolor_dict,index=x.index,columns=x.columns)

    return input_df.style.apply(mycolor,axis=None)

# %%
# Get the summary of the clustering based on the labels in the output column specified
def  clustering_data(cluster_col):
    

    # Sort players data based on no. of innings played
    #players.sort_values(["innings"], ascending = False,inplace=True)
    # Create column for each cluster and insert players in that cluster
    grouper = players.sort_values(["innings"], ascending = False)[['name',cluster_col]].groupby([cluster_col])
    cluster_df = pd.concat([pd.Series(v['name'].tolist(), name=k) for k, v in grouper], axis=1)
    cluster_df.fillna('',inplace=True)
    print("\n-----------------------\nPLAYERS IN EACH CLUSTER\n-----------------------\n")
    display(print_with_column_color_style(cluster_df))
#     search_result = cluster_df.isin(['V Kohli']).any()
#     print(search_result)
    
#     return cluster_summary, cluster_df

# %%
from sklearn.cluster import KMeans

# Define function to perform the kmeans clustering on the given data
def kmeans_clustering(num_clusters, max_iterations,input_df,output_df, output_col):
    kmeans = KMeans(n_clusters=num_clusters, max_iter=max_iterations)
    kmeans.fit(input_df)
    # assign the label to the output column
    output_df[output_col] = kmeans.labels_ 
# New output column to create for the cluster label
kmeans_label = 'cluster_kmeans'

# K-means clustering
kmeans_clustering(5,50,players_scaled[ALL_COLUMN_NAMES],players,kmeans_label)

# %%
clustering_data(kmeans_label)
# Out:
# -----------------------
# PLAYERS IN EACH CLUSTER
# -----------------------
# <style  type="text/css" >
# #T_a6b43_row0_col0,#T_a6b43_row1_col0,#T_a6b43_row2_col0,#T_a6b43_row3_col0,#T_a6b43_row4_col0,#T_a6b43_row5_col0,#T_a6b43_row6_col0,#T_a6b43_row7_col0,#T_a6b43_row8_col0,#T_a6b43_row9_col0,#T_a6b43_row10_col0,#T_a6b43_row11_col0,#T_a6b43_row12_col0,#T_a6b43_row13_col0,#T_a6b43_row14_col0,#T_a6b43_row15_col0,#T_a6b43_row16_col0,#T_a6b43_row17_col0,#T_a6b43_row18_col0,#T_a6b43_row19_col0,#T_a6b43_row20_col0,#T_a6b43_row21_col0,#T_a6b43_row22_col0,#T_a6b43_row23_col0,#T_a6b43_row24_col0,#T_a6b43_row25_col0,#T_a6b43_row26_col0,#T_a6b43_row27_col0,#T_a6b43_row28_col0,#T_a6b43_row29_col0,#T_a6b43_row30_col0,#T_a6b43_row31_col0,#T_a6b43_row32_col0,#T_a6b43_row33_col0,#T_a6b43_row34_col0,#T_a6b43_row35_col0,#T_a6b43_row36_col0,#T_a6b43_row37_col0,#T_a6b43_row38_col0,#T_a6b43_row39_col0,#T_a6b43_row40_col0,#T_a6b43_row41_col0,#T_a6b43_row42_col0,#T_a6b43_row43_col0,#T_a6b43_row44_col0,#T_a6b43_row45_col0,#T_a6b43_row46_col0,#T_a6b43_row47_col0,#T_a6b43_row48_col0,#T_a6b43_row49_col0,#T_a6b43_row50_col0,#T_a6b43_row51_col0,#T_a6b43_row52_col0,#T_a6b43_row53_col0,#T_a6b43_row54_col0,#T_a6b43_row55_col0,#T_a6b43_row56_col0,#T_a6b43_row57_col0,#T_a6b43_row58_col0,#T_a6b43_row59_col0,#T_a6b43_row60_col0,#T_a6b43_row61_col0,#T_a6b43_row62_col0,#T_a6b43_row63_col0,#T_a6b43_row64_col0,#T_a6b43_row65_col0,#T_a6b43_row66_col0,#T_a6b43_row67_col0,#T_a6b43_row68_col0,#T_a6b43_row69_col0,#T_a6b43_row70_col0,#T_a6b43_row71_col0,#T_a6b43_row72_col0,#T_a6b43_row73_col0,#T_a6b43_row74_col0,#T_a6b43_row75_col0,#T_a6b43_row76_col0,#T_a6b43_row77_col0,#T_a6b43_row78_col0,#T_a6b43_row79_col0,#T_a6b43_row80_col0,#T_a6b43_row81_col0,#T_a6b43_row82_col0,#T_a6b43_row83_col0,#T_a6b43_row84_col0,#T_a6b43_row85_col0,#T_a6b43_row86_col0,#T_a6b43_row87_col0,#T_a6b43_row88_col0,#T_a6b43_row89_col0,#T_a6b43_row90_col0,#T_a6b43_row91_col0,#T_a6b43_row92_col0,#T_a6b43_row93_col0,#T_a6b43_row94_col0,#T_a6b43_row95_col0,#T_a6b43_row96_col0,#T_a6b43_row97_col0,#T_a6b43_row98_col0,#T_a6b43_row99_col0,#T_a6b43_row100_col0,#T_a6b43_row101_col0,#T_a6b43_row102_col0,#T_a6b43_row103_col0,#T_a6b43_row104_col0,#T_a6b43_row105_col0,#T_a6b43_row106_col0,#T_a6b43_row107_col0,#T_a6b43_row108_col0,#T_a6b43_row109_col0,#T_a6b43_row110_col0,#T_a6b43_row111_col0,#T_a6b43_row112_col0,#T_a6b43_row113_col0,#T_a6b43_row114_col0,#T_a6b43_row115_col0{
#             background-color: #F28A30;
#         }#T_a6b43_row0_col1,#T_a6b43_row1_col1,#T_a6b43_row2_col1,#T_a6b43_row3_col1,#T_a6b43_row4_col1,#T_a6b43_row5_col1,#T_a6b43_row6_col1,#T_a6b43_row7_col1,#T_a6b43_row8_col1,#T_a6b43_row9_col1,#T_a6b43_row10_col1,#T_a6b43_row11_col1,#T_a6b43_row12_col1,#T_a6b43_row13_col1,#T_a6b43_row14_col1,#T_a6b43_row15_col1,#T_a6b43_row16_col1,#T_a6b43_row17_col1,#T_a6b43_row18_col1,#T_a6b43_row19_col1,#T_a6b43_row20_col1,#T_a6b43_row21_col1,#T_a6b43_row22_col1,#T_a6b43_row23_col1,#T_a6b43_row24_col1,#T_a6b43_row25_col1,#T_a6b43_row26_col1,#T_a6b43_row27_col1,#T_a6b43_row28_col1,#T_a6b43_row29_col1,#T_a6b43_row30_col1,#T_a6b43_row31_col1,#T_a6b43_row32_col1,#T_a6b43_row33_col1,#T_a6b43_row34_col1,#T_a6b43_row35_col1,#T_a6b43_row36_col1,#T_a6b43_row37_col1,#T_a6b43_row38_col1,#T_a6b43_row39_col1,#T_a6b43_row40_col1,#T_a6b43_row41_col1,#T_a6b43_row42_col1,#T_a6b43_row43_col1,#T_a6b43_row44_col1,#T_a6b43_row45_col1,#T_a6b43_row46_col1,#T_a6b43_row47_col1,#T_a6b43_row48_col1,#T_a6b43_row49_col1,#T_a6b43_row50_col1,#T_a6b43_row51_col1,#T_a6b43_row52_col1,#T_a6b43_row53_col1,#T_a6b43_row54_col1,#T_a6b43_row55_col1,#T_a6b43_row56_col1,#T_a6b43_row57_col1,#T_a6b43_row58_col1,#T_a6b43_row59_col1,#T_a6b43_row60_col1,#T_a6b43_row61_col1,#T_a6b43_row62_col1,#T_a6b43_row63_col1,#T_a6b43_row64_col1,#T_a6b43_row65_col1,#T_a6b43_row66_col1,#T_a6b43_row67_col1,#T_a6b43_row68_col1,#T_a6b43_row69_col1,#T_a6b43_row70_col1,#T_a6b43_row71_col1,#T_a6b43_row72_col1,#T_a6b43_row73_col1,#T_a6b43_row74_col1,#T_a6b43_row75_col1,#T_a6b43_row76_col1,#T_a6b43_row77_col1,#T_a6b43_row78_col1,#T_a6b43_row79_col1,#T_a6b43_row80_col1,#T_a6b43_row81_col1,#T_a6b43_row82_col1,#T_a6b43_row83_col1,#T_a6b43_row84_col1,#T_a6b43_row85_col1,#T_a6b43_row86_col1,#T_a6b43_row87_col1,#T_a6b43_row88_col1,#T_a6b43_row89_col1,#T_a6b43_row90_col1,#T_a6b43_row91_col1,#T_a6b43_row92_col1,#T_a6b43_row93_col1,#T_a6b43_row94_col1,#T_a6b43_row95_col1,#T_a6b43_row96_col1,#T_a6b43_row97_col1,#T_a6b43_row98_col1,#T_a6b43_row99_col1,#T_a6b43_row100_col1,#T_a6b43_row101_col1,#T_a6b43_row102_col1,#T_a6b43_row103_col1,#T_a6b43_row104_col1,#T_a6b43_row105_col1,#T_a6b43_row106_col1,#T_a6b43_row107_col1,#T_a6b43_row108_col1,#T_a6b43_row109_col1,#T_a6b43_row110_col1,#T_a6b43_row111_col1,#T_a6b43_row112_col1,#T_a6b43_row113_col1,#T_a6b43_row114_col1,#T_a6b43_row115_col1{
#             background-color: #0ABDA0;
#         }#T_a6b43_row0_col2,#T_a6b43_row1_col2,#T_a6b43_row2_col2,#T_a6b43_row3_col2,#T_a6b43_row4_col2,#T_a6b43_row5_col2,#T_a6b43_row6_col2,#T_a6b43_row7_col2,#T_a6b43_row8_col2,#T_a6b43_row9_col2,#T_a6b43_row10_col2,#T_a6b43_row11_col2,#T_a6b43_row12_col2,#T_a6b43_row13_col2,#T_a6b43_row14_col2,#T_a6b43_row15_col2,#T_a6b43_row16_col2,#T_a6b43_row17_col2,#T_a6b43_row18_col2,#T_a6b43_row19_col2,#T_a6b43_row20_col2,#T_a6b43_row21_col2,#T_a6b43_row22_col2,#T_a6b43_row23_col2,#T_a6b43_row24_col2,#T_a6b43_row25_col2,#T_a6b43_row26_col2,#T_a6b43_row27_col2,#T_a6b43_row28_col2,#T_a6b43_row29_col2,#T_a6b43_row30_col2,#T_a6b43_row31_col2,#T_a6b43_row32_col2,#T_a6b43_row33_col2,#T_a6b43_row34_col2,#T_a6b43_row35_col2,#T_a6b43_row36_col2,#T_a6b43_row37_col2,#T_a6b43_row38_col2,#T_a6b43_row39_col2,#T_a6b43_row40_col2,#T_a6b43_row41_col2,#T_a6b43_row42_col2,#T_a6b43_row43_col2,#T_a6b43_row44_col2,#T_a6b43_row45_col2,#T_a6b43_row46_col2,#T_a6b43_row47_col2,#T_a6b43_row48_col2,#T_a6b43_row49_col2,#T_a6b43_row50_col2,#T_a6b43_row51_col2,#T_a6b43_row52_col2,#T_a6b43_row53_col2,#T_a6b43_row54_col2,#T_a6b43_row55_col2,#T_a6b43_row56_col2,#T_a6b43_row57_col2,#T_a6b43_row58_col2,#T_a6b43_row59_col2,#T_a6b43_row60_col2,#T_a6b43_row61_col2,#T_a6b43_row62_col2,#T_a6b43_row63_col2,#T_a6b43_row64_col2,#T_a6b43_row65_col2,#T_a6b43_row66_col2,#T_a6b43_row67_col2,#T_a6b43_row68_col2,#T_a6b43_row69_col2,#T_a6b43_row70_col2,#T_a6b43_row71_col2,#T_a6b43_row72_col2,#T_a6b43_row73_col2,#T_a6b43_row74_col2,#T_a6b43_row75_col2,#T_a6b43_row76_col2,#T_a6b43_row77_col2,#T_a6b43_row78_col2,#T_a6b43_row79_col2,#T_a6b43_row80_col2,#T_a6b43_row81_col2,#T_a6b43_row82_col2,#T_a6b43_row83_col2,#T_a6b43_row84_col2,#T_a6b43_row85_col2,#T_a6b43_row86_col2,#T_a6b43_row87_col2,#T_a6b43_row88_col2,#T_a6b43_row89_col2,#T_a6b43_row90_col2,#T_a6b43_row91_col2,#T_a6b43_row92_col2,#T_a6b43_row93_col2,#T_a6b43_row94_col2,#T_a6b43_row95_col2,#T_a6b43_row96_col2,#T_a6b43_row97_col2,#T_a6b43_row98_col2,#T_a6b43_row99_col2,#T_a6b43_row100_col2,#T_a6b43_row101_col2,#T_a6b43_row102_col2,#T_a6b43_row103_col2,#T_a6b43_row104_col2,#T_a6b43_row105_col2,#T_a6b43_row106_col2,#T_a6b43_row107_col2,#T_a6b43_row108_col2,#T_a6b43_row109_col2,#T_a6b43_row110_col2,#T_a6b43_row111_col2,#T_a6b43_row112_col2,#T_a6b43_row113_col2,#T_a6b43_row114_col2,#T_a6b43_row115_col2{
#             background-color: #008AC5;
#         }#T_a6b43_row0_col3,#T_a6b43_row1_col3,#T_a6b43_row2_col3,#T_a6b43_row3_col3,#T_a6b43_row4_col3,#T_a6b43_row5_col3,#T_a6b43_row6_col3,#T_a6b43_row7_col3,#T_a6b43_row8_col3,#T_a6b43_row9_col3,#T_a6b43_row10_col3,#T_a6b43_row11_col3,#T_a6b43_row12_col3,#T_a6b43_row13_col3,#T_a6b43_row14_col3,#T_a6b43_row15_col3,#T_a6b43_row16_col3,#T_a6b43_row17_col3,#T_a6b43_row18_col3,#T_a6b43_row19_col3,#T_a6b43_row20_col3,#T_a6b43_row21_col3,#T_a6b43_row22_col3,#T_a6b43_row23_col3,#T_a6b43_row24_col3,#T_a6b43_row25_col3,#T_a6b43_row26_col3,#T_a6b43_row27_col3,#T_a6b43_row28_col3,#T_a6b43_row29_col3,#T_a6b43_row30_col3,#T_a6b43_row31_col3,#T_a6b43_row32_col3,#T_a6b43_row33_col3,#T_a6b43_row34_col3,#T_a6b43_row35_col3,#T_a6b43_row36_col3,#T_a6b43_row37_col3,#T_a6b43_row38_col3,#T_a6b43_row39_col3,#T_a6b43_row40_col3,#T_a6b43_row41_col3,#T_a6b43_row42_col3
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-7aae3de0b0fd> in <module>
# ----> 1 cluster_df.isin(['V Kohli']).any()
#
# NameError: name 'cluster_df' is not defined
